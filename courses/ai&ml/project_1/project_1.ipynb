# %% [markdown]
# # AI Intro
#
# - **AI**: artificial intelligence, any computer capable of human thinking, behaviour and action. E.g. ChatGPT, Copilot, Gemini, Siri, Alexa.
# - **ML**: machine learning, the process of a computer in becoming an AI. E.g. given pictures of dogs and cats, the computer will eventually learn what a dog looks like and what a cat looks like. There are 3 main types of machine learning:
#     - **supervised learning**: learning with labeled data, predicts outcomes
#
#     ![sl](https://github.com/n30-Joker/software_academy/blob/main/courses/ai&ml/project_1/supervised_learning.png?raw=true)
#
#     - **unsupervised learning**: learning in unlabeled data, finding patterns
#
#     ![ul](https://github.com/n30-Joker/software_academy/blob/main/courses/ai&ml/project_1/unsupervised_learning.png?raw=true)
#
#     - **reinforcement learning**: learning through trial-and-error, optimises actions
#
#     ![rl](https://github.com/n30-Joker/software_academy/blob/main/courses/ai&ml/project_1/reinforcement_learning.png?raw=true)
#
#
# - **Datasets**: a large collection of information provided to the AI to train from.
#
# ---
#
# ## Python Basics - Variables
#
# - **Variables**: containers storing information
#     - like a jar storing cookies (data)
#     - Names must always start in lower case
#     - Use snake_case for multiple words
#     - Values can be changed

# %%
score = 1 # assignment - giving a value to the variable
print(score)
# print(Score) # gives NameError
score = 2 # update - replacing previous value with new value
print(score)

my_age = 3
my_age += 2 # modification - changing the value, in this case adding 2
# same as: my_age = my_age + 2
print(my_age)
# Out:
# 1
# 2
# 5

# %% [markdown]
# - **Constants**: similar to variables
#     - like a jar that should never be opened or changed.
#     - Names will be in ALL CAPITALS
#     - Values should not be changed

# %%
WIDTH = 480 # constant
print(WIDTH)
WIDTH = 720 # python allows change, but it is bad practice
print(WIDTH)
# Out:
# 480
# 720

# %% [markdown]
# # Project 1 - Hubble Space Telescope images
#
# **Objective**: explore the topic of astronomy, get familiarised with Python coding and display images of galaxies.
#
# - **Hubble Space Telescope**: large telescope orbiting Earth which captures high-quality pictures of space. It produced the famous "Pillars of Creation" picture, displaying a cloud of gas hiding newborn stars. ![Pillars of Creation](pictures/project_1/Hubble_Pillars_of_Creation.jpg)
# - **Galaxy**: system made up of stars, gas, dust and dark matter, bound together by gravity. They contain millions to trillions of stars. We live in the Milky Way galaxy. ![Milky Way](pictures/project_1/Hubble_Milky_Way.jpg)

# %%
# a library is a collection of code saved somewhere else
import matplotlib.pyplot as plt # helps with drawing graphs
from galaxy_datasets.pytorch import GZHubble 
# Galaxy Zoo - stores images of galaxies caught by the Hubble Space Telescope
# Out:
# GZDESI/GZRings/GZCD not available from galaxy_datasets.pytorch.datasets - skipping

# %% [markdown]
# ![Deep Field of Galaxies](pictures/project_1/GZHubble_deep_field.jpg)
#
# - **Data**: information that is collected, stored, and used for analysis.

# %%
data = GZHubble(root = "../data/GZHubble", download=True)

# %% [markdown]
# - **Eliptical Galaxies**: Galaxies shaped like squashed circles or ovals. They usually have older stars and less gas.
#
# ![Elliptical](pictures/project_1/centaurus_a.png)
#
# - **Spiral Galaxies**: Galaxies that look like pinwheels with a bright center and arms that swirl outwards. They often have lots of gas and new stars forming in the arms.
#
# ![Spiral](pictures/project_1/pinwheel_g.png)
#
# - **Supernova**: Super-bright explosion of a star at the end of its life. It spreads heavy elements (like gold) into space.
#
# ![Supernova](pictures/project_1/supernova.gif)
#
# - **AGN**: Active Galactic Nuclei, super-bright center of some galaxies, powered by a giant black hole absorbing gas - leading to making light and jets of particles.
#
# ![AGN](pictures/project_1/AGN_NASA.jpg)

# %%
data.catalog # extract all the information for every picture downloaded
# Out:
#        smooth-or-featured-hubble_smooth  smooth-or-featured-hubble_features  \
# 0                                  17.0                                19.0
# 1                                  37.0                                 7.0
# 2                                  37.0                                 4.0
# 3                                  28.0                                 3.0
# 4                                  37.0                                 8.0
# ...                                 ...                                 ...
# 80627                             101.0                                23.0
# 80628                              31.0                                11.0
# 80629                              37.0                                 6.0
# 80630                              37.0                                68.0
# 80631                              39.0                                 6.0
#
# ...

# %% [markdown]
# - **ra**: right ascension, x-axis in the celestial map (horizontal).
# - **dec**: declination, y-axis in the celestial map (vertical).
# - **jpg**: Joint Photographic-Experts Group, common digital image file format.
# - **print**: display the information on the screen.

# %%
image_data = data.catalog.iloc[1000]
# get the information of the specific integer location (iloc)
# integer: whole number, e.g. 2, 0, -5
print(image_data)
# Out:
# smooth-or-featured-hubble_smooth                                            34.0
# smooth-or-featured-hubble_features                                           5.0
# smooth-or-featured-hubble_artifact                                           4.0
# how-rounded-hubble_completely                                               27.0
# how-rounded-hubble_in-between                                                7.0
# how-rounded-hubble_cigar-shaped                                              0.0
# clumpy-appearance-hubble_yes                                                 1.0
# clumpy-appearance-hubble_no                                                  4.0
# disk-edge-on-hubble_yes                                                      0.0
# disk-edge-on-hubble_no                                                       4.0
# bulge-shape-hubble_rounded                                                   0.0
# bulge-shape-hubble_boxy                                                      0.0
# ...

# %%
image_file_loc = image_data["file_loc"]
# get the file location from the file_loc column
print(f"The file is stored in: {image_file_loc}") 
# f - format
# string (str) - anything within speech marks ("")
# f"{variable}" - formats the value of the variable into the string

image = plt.imread(image_file_loc) #  image read - uses plt to load the image from the computer

plt.imshow(image) # image show - plots the image onto a graph
plt.imsave("Pictures/picture.jpg", image) # image save - save the image into the desired name
plt.show() # displays the graph
# Out:
# The file is stored in: ../data/GZHubble\images\20057578.jpg

# %% [markdown]
# ## Python Basics
#
# - **Loops**: let the computer repeat actions automatically.
# - There are 2 common types: **WHILE** and **FOR**
#
# - **WHILE**: repeats the code until a certain condition is broken.
#     - Potentially runs forever

# %%
count = 1

# The loop continues while the condition is true
while count <= 5:
    print(count)
    count += 1  # increase the value each loop
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# - **FOR** : repeats the code a certain amount of times.

# %%
# Repeat 5 times
for i in range(5):
    print("Hello!")
# Out:
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!

# %%
for i in range(1, 6): # 1,2,3,4,5 - starts from 1, end before 6
    # print(i) # display the numbers
    # range(start, end(not included))
    image_data = data.catalog.iloc[i*1000] # 1000,2000,3000,4000,5000

    image_file_loc = image_data["file_loc"]

    image = plt.imread(image_file_loc)

    plt.figure(figsize=(2,2)) # resize the graph into 2x2 inches
    plt.imshow(image)
    plt.title(f"Image Number: {i*1000}")
    plt.axis("off") # no need for numbers
    plt.show()

# %% [markdown]
# - **Conditional statements**: logical instructions that let the program make decisions.
#     - **IF**: checks for a certain condition and carry out instructions.
#         - E.g. If the person is younger than 10, set the cinema ticket price to free.
#     - **ELIF**: else if, checks for another certain condition when the one above fails.
#         - E.g. If the person is older than 65, set the cinema ticket price to be 50% off.
#     - **ELSE**: instructions to follow when none of the conditions above are satisfied.
#         - E.g. Full price for the rest (11 to 64 year olds).

# %%
i = 0 # counter- counts the number of pictures loaded/displayed
for row in range(50000):
    image_data = data.catalog.iloc[row]

    if image_data['has-spiral-arms-hubble_yes'] > 20:
        # get only spiral galaxies
        image_file_loc = image_data["file_loc"]

        image = plt.imread(image_file_loc)

        plt.figure(figsize=(2,2))
        plt.imshow(image)
        plt.title(f"Image number: {row}")
        plt.axis("off")
        plt.show()

        i += 1 # increment  - increase little by little
        if i>3: # limit to the first 4 images
            break # stop the loop
